# %% [markdown]
# <a href="https://colab.research.google.com/github/Xin-gif/Chinese-painting/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# !pip install torchvision

# %%
# !pip install visdom
# !pip install dominate
# Out:
# ...
#      |████████████████████████████████| 686kB 16.3MB/s
# ...
#      |████████████████████████████████| 204kB 26.6MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp36-none-any.whl size=655252 sha256=3df7d44f82eeefed50aebde8db2b08ec6c33d964d2608bb7bd5b19531c971228
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp36-none-any.whl size=5713 sha256=4c681ce18f3c9f1186ba8cc84fab28285a6e0a4ed1a3d9499785d01ad324896a
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# ...

# %%
# !git clone https://github.com/qiaott/AncientPainitng2NaturalImage.git
# Out:
# Cloning into 'AncientPainitng2NaturalImage'...
# remote: Enumerating objects: 92, done.
# remote: Total 92 (delta 0), reused 0 (delta 0), pack-reused 92
# Unpacking objects: 100% (92/92), done.

# %%
 # !unrar x bird.rar
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
# Unexpected end of archive
#
# Extracting from bird.rar
#
#
# Would you like to replace the existing file bird/.DS_Store
#  14340 bytes, modified on 2019-03-01 12:33
# with a new one
#  14340 bytes, modified on 2019-03-01 12:33
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit Y
#
#   OK
#
# Would you like to replace the existing file bird/trainA/.DS_Store
# 129028 bytes, modified on 2019-03-01 10:12
# with a new one
# 129028 bytes, modified on 2019-03-01 10:12
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit Yes
#
#   OK
#
# Would you like to replace the existing file bird/trainA/CBP00000.jpg
#  62846 bytes, modified on 2019-03-01 01:42
# with a new one
#  62846 bytes, modified on 2019-03-01 01:42
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit
# User break
#
# User break

# %%
  # !unrar x '/content/drive/MyDrive/bird.rar'
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
cd AncientPainitng2NaturalImage
# Out:
# [Errno 2] No such file or directory: 'AncientPainitng2NaturalImage'
# /content/AncientPainitng2NaturalImage

# %%
# !pip install lr_scheduler
# Out:
# ...
#   Created wheel for lr-scheduler: filename=LR_scheduler-0.1-cp36-none-any.whl size=4583 sha256=b2034772a2b66aa0f141471468483d12bfd295e1cd05bb560df55a497ef1e49e
#   Stored in directory: /root/.cache/pip/wheels/91/23/75/dc805b89df8aecab4aa3b3d45bc28349b382e35129004d989e
# Successfully built lr-scheduler
# ...

# %%
# !pip install torch-lr-scheduler
# Out:
# ...
#   Created wheel for torch-lr-scheduler: filename=torch_lr_scheduler-0.0.6-cp36-none-any.whl size=5141 sha256=ac5dbd1792873da084bd79136f1b733f7a3f2c1373347cd0148b73353fee72a5
#   Stored in directory: /root/.cache/pip/wheels/49/f3/8c/58318b14f1a1da3704808f3fbb722f4cd8de1b957bde3e3c55
# ...
#   Created wheel for json-schema-to-class: filename=json_schema_to_class-0.2.4-cp36-none-any.whl size=6229 sha256=c4507ea324543a1063302cdded67a3e8e84d203678bae2c15e73e88467b5c614
#   Stored in directory: /root/.cache/pip/wheels/05/a5/73/364f9b1d730e6852ba53f56df74c7898448f9a1be0fd3e0d2e
# ...
#   Created wheel for line-chain: filename=line_chain-0.0.4-cp36-none-any.whl size=5515 sha256=5cf0a441c38872b05ec977bc865ed67e59017a6d0948c147b33876890c8c7d27
#   Stored in directory: /root/.cache/pip/wheels/16/6a/b3/7e76960c8699d97071e2d3fc8874ee210da2475c3a6b79e5b9
# ...

# %%
# !chmod +x ./do_train.sh
# !sudo ./do_train.sh
# Out:
# ------------ Options -------------
# alpha_F: 0.5
# alpha_G: 1.0
# batchSize: 1
# beta: 10.0
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: False
# dataroot: /content/AncientPainitng2NaturalImage/bird
# dataset_mode: unaligned
# display_freq: 100
# display_id: 0
# display_port: 8097
# display_single_pane_ncols: 100
# display_winsize: 256
# epoch_count: 1
# fineSize: 256
# gamma: 1.0
# gpu_ids: [0]
# identity: 0.5
# init_type: xavier
# input_nc: 3
# isTrain: True
# loadSize: 286
# lr: 0.0002
# lr_decay_iters: 50
# lr_policy: lambda
# max_dataset_size: inf
# model: DSTN
# nThreads: 2
# n_layers_D: 3
# ndf: 64
# ngf: 64
# niter: 100
# niter_decay: 100
# no_dropout: True
# no_flip: False
# no_html: False
# no_lsgan: False
# norm: instance
# output_nc: 3
# phase: train
# pool_size: 50
# print_freq: 100
# resize_or_crop: resize_and_crop
# save_epoch_freq: 5
# save_latest_freq: 5000
# serial_batches: False
# update_html_freq: 1000
# vgg_model_dir: ./data/vgg
# ...

# %%
# Out:
# Reinitialized existing Git repository in /content/AncientPainitng2NaturalImage/.git/
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@ceba9e63acef.(none)')
# fatal: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-346443367509> in <module>()
#       1 import torchfile
# ----> 2 stuff = torchfile.load('a_bunch_of_stuff.t7')
#
# /usr/local/lib/python3.6/dist-packages/torchfile.py in load(filename, **kwargs)
#     420     to `T7Reader`.
#     421     """
# --> 422     with open(filename, 'rb') as f:
#     423         reader = T7Reader(f, **kwargs)
#     424         return reader.read_obj()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'a_bunch_of_stuff.t7'

# %%
# !pip install utils

# %%
from torch.optim import lr_scheduler
